# %% [markdown]
# ## Generador de código componentes y eventos
# En este Notebook permite generar código en Java para las enumeraciones de los componentes, eventos, los resource bundle y los tipos de logs.

# %%
from tkinter import filedialog
from tkinter import messagebox
import tkinter as tk
import json
import re
import unicodedata

# %% [markdown]
# ## Selección del fichero JSON que contiene los componentes y eventos.

# %%
#https://stackoverflow.com/a/42398049

root = tk.Tk()
# Hide the main window
root.withdraw()
root.call('wm', 'attributes', '.', '-topmost', True)

jsonFile=filedialog.askopenfilename(filetypes=[("Fichero JSON",".json")],title="Selecciona el fichero JSON")

# %gui tk

# %%
with open(jsonFile,"r",encoding='utf-8') as file:
        CM=json.load(file)
        print("Cargado el JSON:", jsonFile)
# Out:
# Cargado el JSON: C:/Users/PC/Downloads/Componentes y eventos.json

# %% [markdown]
# ## Parseamos los elementos del JSON
# Convierte un string en mayusculas, los espacios se cambian por _ y solo se aceptan letras del abecedario y numeros.
# Por ejemplo: "Submission updated". se parsea como "SUBMISSION_UPDATED"

# %%
'''Convierte un string en mayusculas, los espacios se cambian por _ y solo se aceptan letras del abecedario y numeros.
Por ejemplo Submission updated. se parsea como SUBMISSION_UPDATED
'''
def parse(string):
    #Cambiamos las letras con acento por uno sin acento, fuente: https://stackoverflow.com/a/15261831
    parsed=''.join((c for c in unicodedata.normalize('NFD', string) if unicodedata.category(c) != 'Mn'))
    parsed=re.sub(" ","_",parsed) #cambiamos los espacios por _
    parsed=re.sub("[^\w]+","",parsed) #eliminamos todos lo que no sea letra alfabetica ni numero
    return parsed.upper() #to upper

# %%
componentDict={}
eventDict={}
parsedComponentEventDict={}
for component, events in CM.items():
    parsedComponent=parse(component)
    componentDict[parsedComponent]=component
    parsedComponentEventDict[parsedComponent]=[]
    for event in events.keys():
        parsedEvent=parse(event)
        eventDict[parsedEvent]=event
        parsedComponentEventDict[parsedComponent].append(parsedEvent)

# %% [markdown]
# ## Generación de la enumeración componente.
# ## (copiar la salida de la celda y pegar en la clase enum Component)

# %%
#Para la clase enum component, copiar y pegar la salida a la clase enum Component

for k, v in componentDict.items():
    print("\t",k,'("',v,'"),',sep="")
print('\tCOMPONENT_NOT_AVAILABLE("Component not avaible");')
# Out:
# 	ACTIVITY_REPORT("Activity report"),
# 	ASSIGNMENT("Assignment"),
# 	BOOK("Book"),
# 	BOOK_PRINTING("Book printing"),
# 	CHAT("Chat"),
# 	CHOICE("Choice"),
# 	COMMENTS("Comments"),
# 	COURSE_COMPLETION("Course completion"),
# 	COURSE_PARTICIPATION("Course participation"),
# 	DATABASE("Database"),
# 	EVENT_MONITOR("Event monitor"),
# 	EXCEL_SPREADSHEET("Excel spreadsheet"),
# 	EXTERNAL_TOOL("External tool"),
# 	FEEDBACK("Feedback"),
# 	FILE("File"),
# 	FILE_SUBMISSIONS("File submissions"),
# 	FOLDER("Folder"),
# 	FORUM("Forum"),
# 	GLOSSARY("Glossary"),
# 	GRADER_REPORT("Grader report"),
# 	HOTPOT_MODULE("HotPot module"),
# 	IMS_CONTENT_PACKAGE("IMS content package"),
# 	JOURNAL("Journal"),
# 	LESSON("Lesson"),
# 	LIVE_LOGS("Live logs"),
# 	LOGS("Logs"),
# 	ONLINE_TEXT_SUBMISSIONS("Online text submissions"),
# 	OPENDOCUMENT_SPREADSHEET("OpenDocument spreadsheet"),
# 	OUTCOMES_REPORT("Outcomes report"),
# 	OVERVIEW_REPORT("Overview report"),
# 	PAGE("Page"),
# 	QUIZ("Quiz"),
# 	RECYCLE_BIN("Recycle bin"),
# 	SCORM_PACKAGE("SCORM package"),
# 	SINGLE_VIEW("Single view"),
# 	STATISTICS("Statistics"),
# 	SUBMISSION_COMMENTS("Submission comments"),
# 	SURVEY("Survey"),
# 	SYSTEM("System"),
# 	TURNITIN_ASSIGNMENT_2("Turnitin Assignment 2"),
# 	URL("URL"),
# 	USER_REPORT("User report"),
# 	USER_TOURS("User tours"),
# 	WIKI("Wiki"),
# 	WORKSHOP("Workshop"),
# 	COMPONENT_NOT_AVAILABLE("Component not avaible");

# %% [markdown]
# ## Generación de la enumeración eventos
# ## (copiar la salida de la celda y pegar en la clase enum Event)

# %%
#Para la clase enum Event

sortedEventList=sorted(eventDict.items(),key=lambda x:x[0]) # cuidado lo convierte en una lista de tuplas

for k, v in sortedEventList:
    print("\t",k,'("',v,'"),',sep="")
print('\tEVENT_NOT_AVAILABLE("Event not avaible");')
# Out:
# 	ACTIVITY_REPORT_VIEWED("Activity report viewed"),
# 	ADD_SUBMISSION("Add Submission"),
# 	ALL_THE_SUBMISSIONS_ARE_BEING_DOWNLOADED("All the submissions are being downloaded."),
# 	AN_EXTENSION_HAS_BEEN_GRANTED("An extension has been granted."),
# 	AN_ONLINE_TEXT_HAS_BEEN_UPLOADED("An online text has been uploaded."),
# 	ASSESSMENT_EVALUATED("Assessment evaluated"),
# 	ASSIGNMENT_OVERRIDE_CREATED("Assignment override created"),
# 	A_FILE_HAS_BEEN_UPLOADED("A file has been uploaded."),
# 	A_SUBMISSION_HAS_BEEN_SUBMITTED("A submission has been submitted."),
# 	A_SUBMISSION_HAS_BEEN_UPLOADED("A submission has been uploaded."),
# 	BADGE_AWARDED("Badge awarded"),
# 	BADGE_CREATED("Badge created"),
# 	BADGE_CRITERIA_CREATED("Badge criteria created"),
# 	BADGE_ENABLED("Badge enabled"),
# 	BADGE_LISTING_VIEWED("Badge listing viewed"),
# 	BADGE_UPDATED("Badge updated"),
# 	BOOK_PRINTED("Book printed"),
# 	CALENDAR_EVENT_CREATED("Calendar event created"),
# 	CALENDAR_EVENT_DELETED("Calendar event deleted"),
# 	CALENDAR_EVENT_UPDATED("Calendar event updated"),
# 	CALENDAR_SUBSCRIPTION_UPDATED("Calendar subscription updated"),
# 	CATEGORY_HAS_BEEN_CREATED("Category has been created"),
# 	CHAPTER_CREATED("Chapter created"),
# 	CHAPTER_UPDATED("Chapter updated"),
# 	CHAPTER_VIEWED("Chapter viewed"),
# 	CHOICE_ANSWER_ADDED("Choice answer added"),
# 	CHOICE_MADE("Choice made"),
# 	CHOICE_REPORT_VIEWED("Choice report viewed"),
# 	COMMENTS_VIEWED("Comments viewed"),
# 	COMMENT_CREATED("Comment created"),
# 	COMMENT_DELETED("Comment deleted"),
# 	COMPLETION_REPORT_VIEWED("Completion report viewed"),
# 	CONTENT_PAGE_VIEWED("Content page viewed"),
# 	COURSE_ACTIVITY_COMPLETION_UPDATED("Course activity completion updated"),
# 	COURSE_BACKUP_CREATED("Course backup created"),
# 	COURSE_COMPLETED("Course completed"),
# 	COURSE_COMPLETION_UPDATED("Course completion updated"),
# 	COURSE_CONTENT_DELETED("Course content deleted"),
# 	COURSE_CREATED("Course created"),
# 	COURSE_MODULE_CREATED("Course module created"),
# 	COURSE_MODULE_DELETED("Course module deleted"),
# 	COURSE_MODULE_INSTANCE_LIST_VIEWED("Course module instance list viewed"),
# 	COURSE_MODULE_UPDATED("Course module updated"),
# 	COURSE_MODULE_VIEWED("Course module viewed"),
# 	COURSE_RESET_ENDED("Course reset ended"),
# 	COURSE_RESET_STARTED("Course reset started"),
# 	COURSE_RESTORED("Course restored"),
# 	COURSE_SEARCHED("Course searched"),
# 	COURSE_SECTION_CREATED("Course section created"),
# 	COURSE_SECTION_DELETED("Course section deleted"),
# 	COURSE_SECTION_UPDATED("Course section updated"),
# 	COURSE_SUMMARY_VIEWED("Course summary viewed"),
# 	COURSE_UPDATED("Course updated"),
# 	COURSE_USER_REPORT_VIEWED("Course user report viewed"),
# 	COURSE_VIEWED("Course viewed"),
# 	DISCUSSION_CREATED("Discussion created"),
# 	DISCUSSION_DELETED("Discussion deleted"),
# 	DISCUSSION_MOVED("Discussion moved"),
# 	DISCUSSION_PINNED("Discussion pinned"),
# 	DISCUSSION_SUBSCRIPTION_CREATED("Discussion subscription created"),
# 	DISCUSSION_SUBSCRIPTION_DELETED("Discussion subscription deleted"),
# 	DISCUSSION_VIEWED("Discussion viewed"),
# 	ENROLMENT_INSTANCE_CREATED("Enrolment instance created"),
# 	ENROLMENT_INSTANCE_UPDATED("Enrolment instance updated"),
# 	ENTRY_HAS_BEEN_CREATED("Entry has been created"),
# 	ENTRY_HAS_BEEN_UPDATED("Entry has been updated"),
# 	EVIDENCE_CREATED("Evidence created."),
# 	FIELD_CREATED("Field created"),
# 	FIELD_UPDATED("Field updated"),
# 	FOLDER_UPDATED("Folder updated"),
# 	GRADER_REPORT_VIEWED("Grader report viewed"),
# 	GRADE_DELETED("Grade deleted"),
# 	GRADE_OUTCOMES_REPORT_VIEWED("Grade outcomes report viewed"),
# 	GRADE_OVERVIEW_REPORT_VIEWED("Grade overview report viewed"),
# 	GRADE_SINGLE_VIEW_REPORT_VIEWED("Grade single view report viewed."),
# 	GRADE_USER_REPORT_VIEWED("Grade user report viewed"),
# 	GRADING_FORM_VIEWED("Grading form viewed"),
# 	GRADING_TABLE_VIEWED("Grading table viewed"),
# 	GROUPING_DELETED("Grouping deleted"),
# 	GROUP_ASSIGNED_TO_GROUPING("Group assigned to grouping"),
# 	GROUP_CREATED("Group created"),
# 	GROUP_DELETED("Group deleted"),
# 	GROUP_MEMBER_ADDED("Group member added"),
# 	GROUP_MEMBER_REMOVED("Group member removed"),
# 	GROUP_UPDATED("Group updated"),
# 	HOTPOT_ATTEMPT_STARTED("HotPot attempt started"),
# 	HOTPOT_ATTEMPT_SUBMITTED("HotPot attempt submitted"),
# 	ITEM_CREATED("Item created"),
# 	ITEM_DELETED("Item deleted"),
# 	ITEM_RESTORED("Item restored"),
# 	JOURNAL_ENTRIES_VIEWED("Journal entries viewed"),
# 	JOURNAL_ENTRY_CREATED("Journal entry created"),
# 	JOURNAL_ENTRY_UPDATED("Journal entry updated"),
# 	LESSON_ENDED("Lesson ended"),
# 	LESSON_STARTED("Lesson started"),
# 	LIST_SUBMISSIONS("List Submissions"),
# 	LIVE_LOG_REPORT_VIEWED("Live log report viewed"),
# 	LOG_REPORT_VIEWED("Log report viewed"),
# 	MESSAGE_SENT("Message sent"),
# 	NOTES_VIEWED("Notes viewed"),
# 	NOTE_CREATED("Note created"),
# 	OPENDOCUMENT_GRADE_EXPORTED("OpenDocument grade exported"),
# 	OUTLINE_REPORT_VIEWED("Outline report viewed"),
# 	PAGE_CREATED("Page created"),
# 	PAGE_MOVED("Page moved"),
# 	PAGE_UPDATED("Page updated"),
# 	PARTICIPATION_REPORT_VIEWED("Participation report viewed"),
# 	PHASE_SWITCHED("Phase switched"),
# 	POST_CREATED("Post created"),
# 	POST_DELETED("Post deleted"),
# 	POST_UPDATED("Post updated"),
# 	QUESTION_ANSWERED("Question answered"),
# 	QUESTION_CATEGORY_CREATED("Question category created"),
# 	QUESTION_MANUALLY_GRADED("Question manually graded"),
# 	QUESTION_VIEWED("Question viewed"),
# 	QUIZ_ATTEMPT_ABANDONED("Quiz attempt abandoned"),
# 	QUIZ_ATTEMPT_DELETED("Quiz attempt deleted"),
# 	QUIZ_ATTEMPT_PREVIEW_STARTED("Quiz attempt preview started"),
# 	QUIZ_ATTEMPT_REVIEWED("Quiz attempt reviewed"),
# 	QUIZ_ATTEMPT_STARTED("Quiz attempt started"),
# 	QUIZ_ATTEMPT_SUBMITTED("Quiz attempt submitted"),
# 	QUIZ_ATTEMPT_SUMMARY_VIEWED("Quiz attempt summary viewed"),
# 	QUIZ_ATTEMPT_VIEWED("Quiz attempt viewed"),
# 	QUIZ_EDIT_PAGE_VIEWED("Quiz edit page viewed"),
# 	QUIZ_REPORT_VIEWED("Quiz report viewed"),
# 	RECENT_ACTIVITY_VIEWED("Recent activity viewed"),
# 	RECORD_CREATED("Record created"),
# 	RECORD_DELETED("Record deleted"),
# 	RECORD_UPDATED("Record updated"),
# 	ROLE_ASSIGNED("Role assigned"),
# 	ROLE_CAPABILITIES_UPDATED("Role capabilities updated"),
# 	ROLE_UNASSIGNED("Role unassigned"),
# 	RULE_CREATED("Rule created"),
# 	SCO_LAUNCHED("Sco launched"),
# 	SESSIONS_VIEWED("Sessions viewed"),
# 	SOME_CONTENT_HAS_BEEN_POSTED("Some content has been posted."),
# 	STEP_SHOWN("Step shown"),
# 	SUBMISSION_ASSESSED("Submission assessed"),
# 	SUBMISSION_CONFIRMATION_FORM_VIEWED("Submission confirmation form viewed."),
# 	SUBMISSION_CREATED("Submission created"),
# 	SUBMISSION_DELETED("Submission deleted"),
# 	SUBMISSION_FORM_VIEWED("Submission form viewed."),
# 	SUBMISSION_REASSESSED("Submission re-assessed"),
# 	SUBMISSION_UPDATED("Submission updated"),
# 	SUBMISSION_VIEWED("Submission viewed"),
# 	SUBMITTED_SCORM_RAW_SCORE("Submitted SCORM raw score"),
# 	SUBMITTED_SCORM_STATUS("Submitted SCORM status"),
# 	SUBSCRIBERS_VIEWED("Subscribers viewed"),
# 	SUBSCRIPTION_CREATED("Subscription created"),
# 	SUBSCRIPTION_DELETED("Subscription deleted"),
# 	SURVEY_REPORT_VIEWED("Survey report viewed"),
# 	SURVEY_RESPONSE_SUBMITTED("Survey response submitted"),
# 	TAG_ADDED_TO_AN_ITEM("Tag added to an item"),
# 	TEMPLATES_VIEWED("Templates viewed"),
# 	TEMPLATE_UPDATED("Template updated"),
# 	THE_STATE_OF_THE_WORKFLOW_HAS_BEEN_UPDATED("The state of the workflow has been updated."),
# 	THE_STATUS_OF_THE_SUBMISSION_HAS_BEEN_VIEWED("The status of the submission has been viewed."),
# 	THE_SUBMISSIONS_HAVE_BEEN_UNLOCKED_FOR_A_USER("The submissions have been unlocked for a user."),
# 	THE_SUBMISSION_HAS_BEEN_GRADED("The submission has been graded."),
# 	THE_USER_HAS_ACCEPTED_THE_STATEMENT_OF_THE_SUBMISSION("The user has accepted the statement of the submission."),
# 	TOUR_ENDED("Tour ended"),
# 	TOUR_STARTED("Tour started"),
# 	USER_COMPETENCY_RATED_IN_COURSE("User competency rated in course."),
# 	USER_COMPETENCY_VIEWED_IN_A_COURSE("User competency viewed in a course."),
# 	USER_ENROLLED_IN_COURSE("User enrolled in course"),
# 	USER_GRADED("User graded"),
# 	USER_LIST_VIEWED("User list viewed"),
# 	USER_LOG_REPORT_VIEWED("User log report viewed"),
# 	USER_PROFILE_VIEWED("User profile viewed"),
# 	USER_REPORT_VIEWED("User report viewed"),
# 	USER_STATISTICS_REPORT_VIEWED("User statistics report viewed"),
# 	USER_UNENROLLED_FROM_COURSE("User unenrolled from course"),
# 	WIKI_HISTORY_VIEWED("Wiki history viewed"),
# 	WIKI_PAGE_CREATED("Wiki page created"),
# 	WIKI_PAGE_LOCKS_DELETED("Wiki page locks deleted"),
# 	WIKI_PAGE_MAP_VIEWED("Wiki page map viewed"),
# 	WIKI_PAGE_UPDATED("Wiki page updated"),
# 	WIKI_PAGE_VIEWED("Wiki page viewed"),
# 	XLS_GRADE_EXPORTED("XLS grade exported"),
# 	ZIP_ARCHIVE_OF_FOLDER_DOWNLOADED("Zip archive of folder downloaded"),
# 	EVENT_NOT_AVAILABLE("Event not avaible");

# %% [markdown]
# ## Generación del listado de componentes para el Resource Bundle en Inglés
# ## (copiar la salida de la celda y pegar en el Resource Bundle Inglés)

# %%
#Para el resource bundle en ingles
for k,v in componentDict.items():
    print("component.",k.lower(),"=",v,sep="")
# Out:
# component.activity_report=Activity report
# component.assignment=Assignment
# component.book=Book
# component.book_printing=Book printing
# component.chat=Chat
# component.choice=Choice
# component.comments=Comments
# component.course_completion=Course completion
# component.course_participation=Course participation
# component.database=Database
# component.event_monitor=Event monitor
# component.excel_spreadsheet=Excel spreadsheet
# component.external_tool=External tool
# component.feedback=Feedback
# component.file=File
# component.file_submissions=File submissions
# component.folder=Folder
# component.forum=Forum
# component.glossary=Glossary
# component.grader_report=Grader report
# component.hotpot_module=HotPot module
# component.ims_content_package=IMS content package
# component.journal=Journal
# component.lesson=Lesson
# component.live_logs=Live logs
# component.logs=Logs
# component.online_text_submissions=Online text submissions
# component.opendocument_spreadsheet=OpenDocument spreadsheet
# component.outcomes_report=Outcomes report
# component.overview_report=Overview report
# component.page=Page
# component.quiz=Quiz
# component.recycle_bin=Recycle bin
# component.scorm_package=SCORM package
# component.single_view=Single view
# component.statistics=Statistics
# component.submission_comments=Submission comments
# component.survey=Survey
# component.system=System
# component.turnitin_assignment_2=Turnitin Assignment 2
# component.url=URL
# component.user_report=User report
# component.user_tours=User tours
# component.wiki=Wiki
# component.workshop=Workshop

# %% [markdown]
# ## Copiar los componentes del Resource Bundle en Español
# ## 1. Ir al fichero de Resource Bundle en Español y copiar los componentes
# ## 2. Pulsar al enter del input (el input bloquea el flujo de la ejecución)
# ## 3. Guardará en una variable lo que haya en el portapapeles

# %%
#Ejecutar esta celda cuando tengas en el portapapeles los el listado de componentes en español
input("Pulsa enter cuando tengas en el portapapeles los componentes en español del resource bundle.")
pasted=root.clipboard_get()
pasted
# Out:
# Pulsa enter cuando tengas en el portapapeles los componentes en español del resource bundle.
# 'component.activity_report=Informe de actividades\ncomponent.assignment=Tarea\ncomponent.book=Libro\ncomponent.book_printing=Impresión de libros\ncomponent.chat=Chat\ncomponent.choice=Consulta\ncomponent.comments=Comentarios\ncomponent.course_completion=Curso completado\ncomponent.course_participation=Participación del curso\ncomponent.database=Base de datos\ncomponent.event_monitor=Monitor de eventos\ncomponent.excel_spreadsheet=Hoja de cálculo de excel\ncomponent.external_tool=Herramienta externa\ncomponent.feedback=Encuesta\ncomponent.file=Archivo\ncomponent.file_submissions=Envíos de archivos\ncomponent.folder=Carpeta\ncomponent.forum=Foro\ncomponent.glossary=Glosario\ncomponent.grader_report=Informe de calificaciones\ncomponent.guia_docente=Guía docente\ncomponent.hotpot_module=Hotpot module\ncomponent.ims_content_package=Paquete de contenido IMS\ncomponent.journal=Diario\ncomponent.lesson=Lección\ncomponent.live_logs=Registros activos\ncomponent.logs=Registros\ncomponent.online_text_submissions=Envíos de texto online\ncomponent.opendocument_spreadsheet=Opendocument spreadsheet\ncomponent.outcomes_report=Informe de resultados\ncomponent.overview_report=Informe general\ncomponent.page=Página\ncomponent.plain_text_file=Fichero de texto plano\ncomponent.quiz=Cuestionario\ncomponent.recycle_bin=Papelera de reciclaje\ncomponent.scorm_package=Páquete SCORM\ncomponent.single_view=Vista simple'

# %%
spanishComponentsDict={}
spanishComponents=pasted.split("\n")
for e in spanishComponents:
    if len(e)!=0:
        component,traduction=e.split("=")
        component=re.sub("component.","",component) #eliminamos component. que esta al principio
        spanishComponentsDict[component.upper()]=traduction

# %% [markdown]
# ## Generación del listado de componentes para el Resource Bundle en Español
# ## (copiar la salida de la celda y pegar en el Resource Bundle en Español)

# %%
#Copiar y pegar en el resource bundle español el resultado 
for k,v in componentDict.items():
    #si ya existe una entrada en español ponemos su traduccion y si no usamos la traduccion en ingles
    if k in spanishComponentsDict:
        traduccion= spanishComponentsDict[k] 
    else:
        traduccion=v 
        print("#TODO ",end="")
    print("component.",k.lower(),"=",traduccion,sep="")
# Out:
# component.activity_report=Informe de actividades
# component.assignment=Tarea
# component.book=Libro
# component.book_printing=Impresión de libros
# component.chat=Chat
# component.choice=Consulta
# component.comments=Comentarios
# component.course_completion=Curso completado
# component.course_participation=Participación del curso
# component.database=Base de datos
# component.event_monitor=Monitor de eventos
# component.excel_spreadsheet=Hoja de cálculo de excel
# component.external_tool=Herramienta externa
# component.feedback=Encuesta
# component.file=Archivo
# component.file_submissions=Envíos de archivos
# component.folder=Carpeta
# component.forum=Foro
# component.glossary=Glosario
# component.grader_report=Informe de calificaciones
# component.hotpot_module=Hotpot module
# component.ims_content_package=Paquete de contenido IMS
# component.journal=Diario
# component.lesson=Lección
# component.live_logs=Registros activos
# component.logs=Registros
# component.online_text_submissions=Envíos de texto online
# component.opendocument_spreadsheet=Opendocument spreadsheet
# component.outcomes_report=Informe de resultados
# component.overview_report=Informe general
# component.page=Página
# component.quiz=Cuestionario
# component.recycle_bin=Papelera de reciclaje
# component.scorm_package=Páquete SCORM
# component.single_view=Vista simple
# #TODO component.statistics=Statistics
# #TODO component.submission_comments=Submission comments
# #TODO component.survey=Survey
# #TODO component.system=System
# #TODO component.turnitin_assignment_2=Turnitin Assignment 2
# #TODO component.url=URL
# #TODO component.user_report=User report
# #TODO component.user_tours=User tours
# #TODO component.wiki=Wiki
# #TODO component.workshop=Workshop

# %% [markdown]
# ## Generación del listado de eventos para el Resource Bundle en Inglés
# ## (copiar la salida de la celda y pegar en el Resource Bundle Inglés)

# %%
for k,v in sortedEventList:
    print("eventname.",k.lower(),"=",v,sep="")
# Out:
# eventname.activity_report_viewed=Activity report viewed
# eventname.add_submission=Add Submission
# eventname.all_the_submissions_are_being_downloaded=All the submissions are being downloaded.
# eventname.an_extension_has_been_granted=An extension has been granted.
# eventname.an_online_text_has_been_uploaded=An online text has been uploaded.
# eventname.assessment_evaluated=Assessment evaluated
# eventname.assignment_override_created=Assignment override created
# eventname.a_file_has_been_uploaded=A file has been uploaded.
# eventname.a_submission_has_been_submitted=A submission has been submitted.
# eventname.a_submission_has_been_uploaded=A submission has been uploaded.
# eventname.badge_awarded=Badge awarded
# eventname.badge_created=Badge created
# eventname.badge_criteria_created=Badge criteria created
# eventname.badge_enabled=Badge enabled
# eventname.badge_listing_viewed=Badge listing viewed
# eventname.badge_updated=Badge updated
# eventname.book_printed=Book printed
# eventname.calendar_event_created=Calendar event created
# eventname.calendar_event_deleted=Calendar event deleted
# eventname.calendar_event_updated=Calendar event updated
# eventname.calendar_subscription_updated=Calendar subscription updated
# eventname.category_has_been_created=Category has been created
# eventname.chapter_created=Chapter created
# eventname.chapter_updated=Chapter updated
# eventname.chapter_viewed=Chapter viewed
# eventname.choice_answer_added=Choice answer added
# eventname.choice_made=Choice made
# eventname.choice_report_viewed=Choice report viewed
# eventname.comments_viewed=Comments viewed
# eventname.comment_created=Comment created
# eventname.comment_deleted=Comment deleted
# eventname.completion_report_viewed=Completion report viewed
# eventname.content_page_viewed=Content page viewed
# eventname.course_activity_completion_updated=Course activity completion updated
# eventname.course_backup_created=Course backup created
# eventname.course_completed=Course completed
# eventname.course_completion_updated=Course completion updated
# eventname.course_content_deleted=Course content deleted
# eventname.course_created=Course created
# eventname.course_module_created=Course module created
# eventname.course_module_deleted=Course module deleted
# eventname.course_module_instance_list_viewed=Course module instance list viewed
# eventname.course_module_updated=Course module updated
# eventname.course_module_viewed=Course module viewed
# eventname.course_reset_ended=Course reset ended
# eventname.course_reset_started=Course reset started
# eventname.course_restored=Course restored
# eventname.course_searched=Course searched
# eventname.course_section_created=Course section created
# eventname.course_section_deleted=Course section deleted
# eventname.course_section_updated=Course section updated
# eventname.course_summary_viewed=Course summary viewed
# eventname.course_updated=Course updated
# eventname.course_user_report_viewed=Course user report viewed
# eventname.course_viewed=Course viewed
# eventname.discussion_created=Discussion created
# eventname.discussion_deleted=Discussion deleted
# eventname.discussion_moved=Discussion moved
# eventname.discussion_pinned=Discussion pinned
# eventname.discussion_subscription_created=Discussion subscription created
# eventname.discussion_subscription_deleted=Discussion subscription deleted
# eventname.discussion_viewed=Discussion viewed
# eventname.enrolment_instance_created=Enrolment instance created
# eventname.enrolment_instance_updated=Enrolment instance updated
# eventname.entry_has_been_created=Entry has been created
# eventname.entry_has_been_updated=Entry has been updated
# eventname.evidence_created=Evidence created.
# eventname.field_created=Field created
# eventname.field_updated=Field updated
# eventname.folder_updated=Folder updated
# eventname.grader_report_viewed=Grader report viewed
# eventname.grade_deleted=Grade deleted
# eventname.grade_outcomes_report_viewed=Grade outcomes report viewed
# eventname.grade_overview_report_viewed=Grade overview report viewed
# eventname.grade_single_view_report_viewed=Grade single view report viewed.
# eventname.grade_user_report_viewed=Grade user report viewed
# eventname.grading_form_viewed=Grading form viewed
# eventname.grading_table_viewed=Grading table viewed
# eventname.grouping_deleted=Grouping deleted
# eventname.group_assigned_to_grouping=Group assigned to grouping
# eventname.group_created=Group created
# eventname.group_deleted=Group deleted
# eventname.group_member_added=Group member added
# eventname.group_member_removed=Group member removed
# eventname.group_updated=Group updated
# eventname.hotpot_attempt_started=HotPot attempt started
# eventname.hotpot_attempt_submitted=HotPot attempt submitted
# eventname.item_created=Item created
# eventname.item_deleted=Item deleted
# eventname.item_restored=Item restored
# eventname.journal_entries_viewed=Journal entries viewed
# eventname.journal_entry_created=Journal entry created
# eventname.journal_entry_updated=Journal entry updated
# eventname.lesson_ended=Lesson ended
# eventname.lesson_started=Lesson started
# eventname.list_submissions=List Submissions
# eventname.live_log_report_viewed=Live log report viewed
# eventname.log_report_viewed=Log report viewed
# eventname.message_sent=Message sent
# eventname.notes_viewed=Notes viewed
# eventname.note_created=Note created
# eventname.opendocument_grade_exported=OpenDocument grade exported
# eventname.outline_report_viewed=Outline report viewed
# eventname.page_created=Page created
# eventname.page_moved=Page moved
# eventname.page_updated=Page updated
# eventname.participation_report_viewed=Participation report viewed
# eventname.phase_switched=Phase switched
# eventname.post_created=Post created
# eventname.post_deleted=Post deleted
# eventname.post_updated=Post updated
# eventname.question_answered=Question answered
# eventname.question_category_created=Question category created
# eventname.question_manually_graded=Question manually graded
# eventname.question_viewed=Question viewed
# eventname.quiz_attempt_abandoned=Quiz attempt abandoned
# eventname.quiz_attempt_deleted=Quiz attempt deleted
# eventname.quiz_attempt_preview_started=Quiz attempt preview started
# eventname.quiz_attempt_reviewed=Quiz attempt reviewed
# eventname.quiz_attempt_started=Quiz attempt started
# eventname.quiz_attempt_submitted=Quiz attempt submitted
# eventname.quiz_attempt_summary_viewed=Quiz attempt summary viewed
# eventname.quiz_attempt_viewed=Quiz attempt viewed
# eventname.quiz_edit_page_viewed=Quiz edit page viewed
# eventname.quiz_report_viewed=Quiz report viewed
# eventname.recent_activity_viewed=Recent activity viewed
# eventname.record_created=Record created
# eventname.record_deleted=Record deleted
# eventname.record_updated=Record updated
# eventname.role_assigned=Role assigned
# eventname.role_capabilities_updated=Role capabilities updated
# eventname.role_unassigned=Role unassigned
# eventname.rule_created=Rule created
# eventname.sco_launched=Sco launched
# eventname.sessions_viewed=Sessions viewed
# eventname.some_content_has_been_posted=Some content has been posted.
# eventname.step_shown=Step shown
# eventname.submission_assessed=Submission assessed
# eventname.submission_confirmation_form_viewed=Submission confirmation form viewed.
# eventname.submission_created=Submission created
# eventname.submission_deleted=Submission deleted
# eventname.submission_form_viewed=Submission form viewed.
# eventname.submission_reassessed=Submission re-assessed
# eventname.submission_updated=Submission updated
# eventname.submission_viewed=Submission viewed
# eventname.submitted_scorm_raw_score=Submitted SCORM raw score
# eventname.submitted_scorm_status=Submitted SCORM status
# eventname.subscribers_viewed=Subscribers viewed
# eventname.subscription_created=Subscription created
# eventname.subscription_deleted=Subscription deleted
# eventname.survey_report_viewed=Survey report viewed
# eventname.survey_response_submitted=Survey response submitted
# eventname.tag_added_to_an_item=Tag added to an item
# eventname.templates_viewed=Templates viewed
# eventname.template_updated=Template updated
# eventname.the_state_of_the_workflow_has_been_updated=The state of the workflow has been updated.
# eventname.the_status_of_the_submission_has_been_viewed=The status of the submission has been viewed.
# eventname.the_submissions_have_been_unlocked_for_a_user=The submissions have been unlocked for a user.
# eventname.the_submission_has_been_graded=The submission has been graded.
# eventname.the_user_has_accepted_the_statement_of_the_submission=The user has accepted the statement of the submission.
# eventname.tour_ended=Tour ended
# eventname.tour_started=Tour started
# eventname.user_competency_rated_in_course=User competency rated in course.
# eventname.user_competency_viewed_in_a_course=User competency viewed in a course.
# eventname.user_enrolled_in_course=User enrolled in course
# eventname.user_graded=User graded
# eventname.user_list_viewed=User list viewed
# eventname.user_log_report_viewed=User log report viewed
# eventname.user_profile_viewed=User profile viewed
# eventname.user_report_viewed=User report viewed
# eventname.user_statistics_report_viewed=User statistics report viewed
# eventname.user_unenrolled_from_course=User unenrolled from course
# eventname.wiki_history_viewed=Wiki history viewed
# eventname.wiki_page_created=Wiki page created
# eventname.wiki_page_locks_deleted=Wiki page locks deleted
# eventname.wiki_page_map_viewed=Wiki page map viewed
# eventname.wiki_page_updated=Wiki page updated
# eventname.wiki_page_viewed=Wiki page viewed
# eventname.xls_grade_exported=XLS grade exported
# eventname.zip_archive_of_folder_downloaded=Zip archive of folder downloaded

# %% [markdown]
# ## Copiar los eventos del Resource Bundle en Español
# ## 1. Ir al fichero de Resource Bundle en Español y copiar los eventos
# ## 2. Pulsar al enter del input (el input bloquea el flujo de la ejecución)
# ## 3. Guardará en una variable lo que haya en el portapapeles

# %%
#Ejecutar esta celda cuando tengas en el portapapeles los el listado de componentes en español
input("Pulsa enter cuando tengas en el portapepeles los eventnames en español del resource bundle.")
pasted=root.clipboard_get()
pasted
# Out:
# Pulsa enter cuando tengas en el portapepeles los eventnames en español del resource bundle.
# 'eventname.activity_report_viewed=Informe de actividad visto\neventname.add_submission=Agregar entrega\neventname.all_the_submissions_are_being_downloaded=Todas las entregas están siendo descargadas.\neventname.an_extension_has_been_granted=Se ha concedido una prórroga..\neventname.an_online_text_has_been_uploaded=Se ha subido un texto en línea.\neventname.assessment_evaluated=Evaluación evaluada\neventname.assignment_override_created=Anulación de asignación creada\neventname.assignment_override_deleted=Anulación de asignación eliminada\neventname.assignment_override_updated=Anulación de asignación actualizada\neventname.a_file_has_been_uploaded=Se ha subido un archivo.\neventname.a_submission_has_been_submitted=Una presentación ha sido enviada.\neventname.a_submission_has_been_uploaded=A submission has been uploaded.\neventname.badge_listing_viewed=Listado de la insignia visto\neventname.book_printed=Libro impreso\neventname.calendar_event_created=Evento calendario creado\neventname.calendar_event_deleted=Evento del calendario eliminado\neventname.calendar_event_updated=Evento calendario actualizado\neventname.calendar_subscription_updated=Calendar subscription updated\neventname.category_has_been_created=Categoría ha sido creada\neventname.chapter_created=Capítulo creado\neventname.chapter_updated=Capítulo actualizado\neventname.chapter_viewed=Capítulo visto\neventname.choice_answer_added=Respuesta de elección añadida\neventname.choice_made=Elección hecha\neventname.choice_report_viewed=Informe de elección visto\neventname.comments_viewed=Comentarios visto\neventname.comment_created=Comentario creado\neventname.comment_deleted=Comentario borrado\neventname.completion_report_viewed=Informe completo visto\neventname.content_page_viewed=Contenido de la página visto\neventname.course_activity_completion_updated=Finalización de la actividad del curso actualizada.\neventname.course_backup_created=Copia de seguridad del curso creado\neventname.course_completed=Curso completado\neventname.course_completion_updated=Curso completado actualizado\neventname.course_content_deleted=Contenido del curso eliminado'

# %%
spanishEventsDict={}
spanishEvents=pasted.split("\n")
for e in spanishEvents:
    if len(e)!=0:
        event,traduction=e.split("=")
        event=re.sub("eventname.","",event) #eliminamos component. que esta al principio
        spanishEventsDict[event.upper()]=traduction

# %% [markdown]
# ## Generación del listado de eventos para el Resource Bundle en Español
# ## (copiar la salida de la celda y pegar en el Resource Bundle Español)

# %%
#Copiar y pegar en el resource bundle español el resultado 
for k,v in sortedEventList:
    #si ya existe una entrada en español ponemos su traduccion y si no usamos la traduccion en ingles
    if k in spanishEventsDict:
        traduccion= spanishEventsDict[k] 
    else:
        traduccion=v 
        print("#TODO ",end="")
    print("eventname.",k.lower(),"=",traduccion,sep="")
# Out:
# eventname.activity_report_viewed=Informe de actividad visto
# eventname.add_submission=Agregar entrega
# eventname.all_the_submissions_are_being_downloaded=Todas las entregas están siendo descargadas.
# eventname.an_extension_has_been_granted=Se ha concedido una prórroga..
# eventname.an_online_text_has_been_uploaded=Se ha subido un texto en línea.
# eventname.assessment_evaluated=Evaluación evaluada
# eventname.assignment_override_created=Anulación de asignación creada
# eventname.a_file_has_been_uploaded=Se ha subido un archivo.
# eventname.a_submission_has_been_submitted=Una presentación ha sido enviada.
# eventname.a_submission_has_been_uploaded=A submission has been uploaded.
# #TODO eventname.badge_awarded=Badge awarded
# #TODO eventname.badge_created=Badge created
# #TODO eventname.badge_criteria_created=Badge criteria created
# #TODO eventname.badge_enabled=Badge enabled
# eventname.badge_listing_viewed=Listado de la insignia visto
# #TODO eventname.badge_updated=Badge updated
# eventname.book_printed=Libro impreso
# eventname.calendar_event_created=Evento calendario creado
# eventname.calendar_event_deleted=Evento del calendario eliminado
# eventname.calendar_event_updated=Evento calendario actualizado
# eventname.calendar_subscription_updated=Calendar subscription updated
# eventname.category_has_been_created=Categoría ha sido creada
# eventname.chapter_created=Capítulo creado
# eventname.chapter_updated=Capítulo actualizado
# eventname.chapter_viewed=Capítulo visto
# eventname.choice_answer_added=Respuesta de elección añadida
# eventname.choice_made=Elección hecha
# eventname.choice_report_viewed=Informe de elección visto
# eventname.comments_viewed=Comentarios visto
# eventname.comment_created=Comentario creado
# eventname.comment_deleted=Comentario borrado
# eventname.completion_report_viewed=Informe completo visto
# eventname.content_page_viewed=Contenido de la página visto
# eventname.course_activity_completion_updated=Finalización de la actividad del curso actualizada.
# eventname.course_backup_created=Copia de seguridad del curso creado
# eventname.course_completed=Curso completado
# eventname.course_completion_updated=Curso completado actualizado
# eventname.course_content_deleted=Contenido del curso eliminado
# #TODO eventname.course_created=Course created
# #TODO eventname.course_module_created=Course module created
# #TODO eventname.course_module_deleted=Course module deleted
# #TODO eventname.course_module_instance_list_viewed=Course module instance list viewed
# #TODO eventname.course_module_updated=Course module updated
# #TODO eventname.course_module_viewed=Course module viewed
# #TODO eventname.course_reset_ended=Course reset ended
# #TODO eventname.course_reset_started=Course reset started
# #TODO eventname.course_restored=Course restored
# #TODO eventname.course_searched=Course searched
# #TODO eventname.course_section_created=Course section created
# #TODO eventname.course_section_deleted=Course section deleted
# #TODO eventname.course_section_updated=Course section updated
# #TODO eventname.course_summary_viewed=Course summary viewed
# #TODO eventname.course_updated=Course updated
# #TODO eventname.course_user_report_viewed=Course user report viewed
# #TODO eventname.course_viewed=Course viewed
# #TODO eventname.discussion_created=Discussion created
# #TODO eventname.discussion_deleted=Discussion deleted
# #TODO eventname.discussion_moved=Discussion moved
# #TODO eventname.discussion_pinned=Discussion pinned
# #TODO eventname.discussion_subscription_created=Discussion subscription created
# #TODO eventname.discussion_subscription_deleted=Discussion subscription deleted
# #TODO eventname.discussion_viewed=Discussion viewed
# #TODO eventname.enrolment_instance_created=Enrolment instance created
# #TODO eventname.enrolment_instance_updated=Enrolment instance updated
# #TODO eventname.entry_has_been_created=Entry has been created
# #TODO eventname.entry_has_been_updated=Entry has been updated
# #TODO eventname.evidence_created=Evidence created.
# #TODO eventname.field_created=Field created
# #TODO eventname.field_updated=Field updated
# #TODO eventname.folder_updated=Folder updated
# #TODO eventname.grader_report_viewed=Grader report viewed
# #TODO eventname.grade_deleted=Grade deleted
# #TODO eventname.grade_outcomes_report_viewed=Grade outcomes report viewed
# #TODO eventname.grade_overview_report_viewed=Grade overview report viewed
# #TODO eventname.grade_single_view_report_viewed=Grade single view report viewed.
# #TODO eventname.grade_user_report_viewed=Grade user report viewed
# #TODO eventname.grading_form_viewed=Grading form viewed
# #TODO eventname.grading_table_viewed=Grading table viewed
# #TODO eventname.grouping_deleted=Grouping deleted
# #TODO eventname.group_assigned_to_grouping=Group assigned to grouping
# #TODO eventname.group_created=Group created
# #TODO eventname.group_deleted=Group deleted
# #TODO eventname.group_member_added=Group member added
# #TODO eventname.group_member_removed=Group member removed
# #TODO eventname.group_updated=Group updated
# #TODO eventname.hotpot_attempt_started=HotPot attempt started
# #TODO eventname.hotpot_attempt_submitted=HotPot attempt submitted
# #TODO eventname.item_created=Item created
# #TODO eventname.item_deleted=Item deleted
# #TODO eventname.item_restored=Item restored
# #TODO eventname.journal_entries_viewed=Journal entries viewed
# #TODO eventname.journal_entry_created=Journal entry created
# #TODO eventname.journal_entry_updated=Journal entry updated
# #TODO eventname.lesson_ended=Lesson ended
# #TODO eventname.lesson_started=Lesson started
# #TODO eventname.list_submissions=List Submissions
# #TODO eventname.live_log_report_viewed=Live log report viewed
# #TODO eventname.log_report_viewed=Log report viewed
# #TODO eventname.message_sent=Message sent
# #TODO eventname.notes_viewed=Notes viewed
# #TODO eventname.note_created=Note created
# #TODO eventname.opendocument_grade_exported=OpenDocument grade exported
# #TODO eventname.outline_report_viewed=Outline report viewed
# #TODO eventname.page_created=Page created
# #TODO eventname.page_moved=Page moved
# #TODO eventname.page_updated=Page updated
# #TODO eventname.participation_report_viewed=Participation report viewed
# #TODO eventname.phase_switched=Phase switched
# #TODO eventname.post_created=Post created
# #TODO eventname.post_deleted=Post deleted
# #TODO eventname.post_updated=Post updated
# #TODO eventname.question_answered=Question answered
# #TODO eventname.question_category_created=Question category created
# #TODO eventname.question_manually_graded=Question manually graded
# #TODO eventname.question_viewed=Question viewed
# #TODO eventname.quiz_attempt_abandoned=Quiz attempt abandoned
# #TODO eventname.quiz_attempt_deleted=Quiz attempt deleted
# #TODO eventname.quiz_attempt_preview_started=Quiz attempt preview started
# #TODO eventname.quiz_attempt_reviewed=Quiz attempt reviewed
# #TODO eventname.quiz_attempt_started=Quiz attempt started
# #TODO eventname.quiz_attempt_submitted=Quiz attempt submitted
# #TODO eventname.quiz_attempt_summary_viewed=Quiz attempt summary viewed
# #TODO eventname.quiz_attempt_viewed=Quiz attempt viewed
# #TODO eventname.quiz_edit_page_viewed=Quiz edit page viewed
# #TODO eventname.quiz_report_viewed=Quiz report viewed
# #TODO eventname.recent_activity_viewed=Recent activity viewed
# #TODO eventname.record_created=Record created
# #TODO eventname.record_deleted=Record deleted
# #TODO eventname.record_updated=Record updated
# #TODO eventname.role_assigned=Role assigned
# #TODO eventname.role_capabilities_updated=Role capabilities updated
# #TODO eventname.role_unassigned=Role unassigned
# #TODO eventname.rule_created=Rule created
# #TODO eventname.sco_launched=Sco launched
# #TODO eventname.sessions_viewed=Sessions viewed
# #TODO eventname.some_content_has_been_posted=Some content has been posted.
# #TODO eventname.step_shown=Step shown
# #TODO eventname.submission_assessed=Submission assessed
# #TODO eventname.submission_confirmation_form_viewed=Submission confirmation form viewed.
# #TODO eventname.submission_created=Submission created
# #TODO eventname.submission_deleted=Submission deleted
# #TODO eventname.submission_form_viewed=Submission form viewed.
# #TODO eventname.submission_reassessed=Submission re-assessed
# #TODO eventname.submission_updated=Submission updated
# #TODO eventname.submission_viewed=Submission viewed
# #TODO eventname.submitted_scorm_raw_score=Submitted SCORM raw score
# #TODO eventname.submitted_scorm_status=Submitted SCORM status
# #TODO eventname.subscribers_viewed=Subscribers viewed
# #TODO eventname.subscription_created=Subscription created
# #TODO eventname.subscription_deleted=Subscription deleted
# #TODO eventname.survey_report_viewed=Survey report viewed
# #TODO eventname.survey_response_submitted=Survey response submitted
# #TODO eventname.tag_added_to_an_item=Tag added to an item
# #TODO eventname.templates_viewed=Templates viewed
# #TODO eventname.template_updated=Template updated
# #TODO eventname.the_state_of_the_workflow_has_been_updated=The state of the workflow has been updated.
# #TODO eventname.the_status_of_the_submission_has_been_viewed=The status of the submission has been viewed.
# #TODO eventname.the_submissions_have_been_unlocked_for_a_user=The submissions have been unlocked for a user.
# #TODO eventname.the_submission_has_been_graded=The submission has been graded.
# #TODO eventname.the_user_has_accepted_the_statement_of_the_submission=The user has accepted the statement of the submission.
# #TODO eventname.tour_ended=Tour ended
# #TODO eventname.tour_started=Tour started
# #TODO eventname.user_competency_rated_in_course=User competency rated in course.
# #TODO eventname.user_competency_viewed_in_a_course=User competency viewed in a course.
# #TODO eventname.user_enrolled_in_course=User enrolled in course
# #TODO eventname.user_graded=User graded
# #TODO eventname.user_list_viewed=User list viewed
# #TODO eventname.user_log_report_viewed=User log report viewed
# #TODO eventname.user_profile_viewed=User profile viewed
# #TODO eventname.user_report_viewed=User report viewed
# #TODO eventname.user_statistics_report_viewed=User statistics report viewed
# #TODO eventname.user_unenrolled_from_course=User unenrolled from course
# #TODO eventname.wiki_history_viewed=Wiki history viewed
# #TODO eventname.wiki_page_created=Wiki page created
# #TODO eventname.wiki_page_locks_deleted=Wiki page locks deleted
# #TODO eventname.wiki_page_map_viewed=Wiki page map viewed
# #TODO eventname.wiki_page_updated=Wiki page updated
# #TODO eventname.wiki_page_viewed=Wiki page viewed
# #TODO eventname.xls_grade_exported=XLS grade exported
# #TODO eventname.zip_archive_of_folder_downloaded=Zip archive of folder downloaded

# %% [markdown]
# ## Copiar los put del map logTypes de controllers.ubulogs.logtypes.LogTypes
# ## 1. Ir al fichero de controllers.ubulogs.logcreator.logtypes.LogTypes y copiar los put del map logTypes
# ## 2. Pulsar al enter del input (el input bloquea el flujo de la ejecución)
# ## 3. Guardará en una variable lo que haya en el portapapeles

# %%
#copiar el contenido 
input("Copias los logTypes de controllers.ubulogs.logtypes.LogTypes")
pastedLogReferences=root.clipboard_get()
pastedLogReferences
# Out:
# Copias los logTypes de controllers.ubulogs.logtypes.ReferencesLog
# 'LogTypes'

# %%
listLogTypes=pastedLogReferences.split("\n")
actualLogTypes={}
for logType in listLogTypes:
    match=re.search("Component.(\w+), Event.(\w+)",logType)
    if match:
        actualLogTypes[(match.group(1),match.group(2))]=logType

# %% [markdown]
# ## Generación los pares componente-evento
# ## (copiar la salida de la celda y pegar en controllers.ubulogs.logcreator.logtypes.ReferencesLog)

# %%
for component, events in parsedComponentEventDict.items():
    print()#dejamos una linea en blanco entre diferentes componentes
    for event in events:
        if (component,event) in actualLogTypes:
            print(actualLogTypes[(component,event)])
        else:
            print("\t\tTYPES.put(get(",component,", ",event,"), Default.getInstance()); //TODO",sep="")
# Out:
# 		TYPES.put(get(ACTIVITY_REPORT, ACTIVITY_REPORT_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ACTIVITY_REPORT, OUTLINE_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(ASSIGNMENT, A_SUBMISSION_HAS_BEEN_SUBMITTED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, ALL_THE_SUBMISSIONS_ARE_BEING_DOWNLOADED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, AN_EXTENSION_HAS_BEEN_GRANTED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, ASSIGNMENT_OVERRIDE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, GRADING_FORM_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, GRADING_TABLE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, SUBMISSION_CONFIRMATION_FORM_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, SUBMISSION_FORM_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, SUBMISSION_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, THE_STATE_OF_THE_WORKFLOW_HAS_BEEN_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, THE_STATUS_OF_THE_SUBMISSION_HAS_BEEN_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, THE_SUBMISSION_HAS_BEEN_GRADED), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, THE_SUBMISSIONS_HAVE_BEEN_UNLOCKED_FOR_A_USER), Default.getInstance()); //TODO
# 		TYPES.put(get(ASSIGNMENT, THE_USER_HAS_ACCEPTED_THE_STATEMENT_OF_THE_SUBMISSION), Default.getInstance()); //TODO
#
# 		TYPES.put(get(BOOK, CHAPTER_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(BOOK, CHAPTER_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(BOOK, CHAPTER_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(BOOK, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(BOOK_PRINTING, BOOK_PRINTED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(CHAT, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(CHAT, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(CHAT, MESSAGE_SENT), Default.getInstance()); //TODO
# 		TYPES.put(get(CHAT, SESSIONS_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(CHOICE, CHOICE_ANSWER_ADDED), Default.getInstance()); //TODO
# 		TYPES.put(get(CHOICE, CHOICE_MADE), Default.getInstance()); //TODO
# 		TYPES.put(get(CHOICE, CHOICE_REPORT_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(CHOICE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(COMMENTS, COMMENT_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(COMMENTS, COMMENT_DELETED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(COURSE_COMPLETION, COMPLETION_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(COURSE_PARTICIPATION, PARTICIPATION_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(DATABASE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, FIELD_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, FIELD_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, RECORD_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, RECORD_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, RECORD_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, TEMPLATE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(DATABASE, TEMPLATES_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(EVENT_MONITOR, RULE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(EVENT_MONITOR, SUBSCRIPTION_CREATED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(EXCEL_SPREADSHEET, XLS_GRADE_EXPORTED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(EXTERNAL_TOOL, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(FEEDBACK, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(FEEDBACK, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(FILE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(FILE_SUBMISSIONS, A_FILE_HAS_BEEN_UPLOADED), Default.getInstance()); //TODO
# 		TYPES.put(get(FILE_SUBMISSIONS, SUBMISSION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FILE_SUBMISSIONS, SUBMISSION_UPDATED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(FOLDER, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(FOLDER, FOLDER_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FOLDER, ZIP_ARCHIVE_OF_FOLDER_DOWNLOADED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(FORUM, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, COURSE_SEARCHED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_MOVED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_PINNED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_SUBSCRIPTION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_SUBSCRIPTION_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, DISCUSSION_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, POST_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, POST_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, POST_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, SOME_CONTENT_HAS_BEEN_POSTED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, SUBSCRIBERS_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, SUBSCRIPTION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, SUBSCRIPTION_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(FORUM, USER_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(GLOSSARY, CATEGORY_HAS_BEEN_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(GLOSSARY, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(GLOSSARY, ENTRY_HAS_BEEN_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(GLOSSARY, ENTRY_HAS_BEEN_UPDATED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(GRADER_REPORT, GRADER_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(HOTPOT_MODULE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(HOTPOT_MODULE, HOTPOT_ATTEMPT_STARTED), Default.getInstance()); //TODO
# 		TYPES.put(get(HOTPOT_MODULE, HOTPOT_ATTEMPT_SUBMITTED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(IMS_CONTENT_PACKAGE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(JOURNAL, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(JOURNAL, JOURNAL_ENTRIES_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(JOURNAL, JOURNAL_ENTRY_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(JOURNAL, JOURNAL_ENTRY_UPDATED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(LESSON, CONTENT_PAGE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, LESSON_ENDED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, LESSON_STARTED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, PAGE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, PAGE_MOVED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, PAGE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, QUESTION_ANSWERED), Default.getInstance()); //TODO
# 		TYPES.put(get(LESSON, QUESTION_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(LIVE_LOGS, LIVE_LOG_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(LOGS, LOG_REPORT_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(LOGS, USER_LOG_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(ONLINE_TEXT_SUBMISSIONS, AN_ONLINE_TEXT_HAS_BEEN_UPLOADED), Default.getInstance()); //TODO
# 		TYPES.put(get(ONLINE_TEXT_SUBMISSIONS, SUBMISSION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(ONLINE_TEXT_SUBMISSIONS, SUBMISSION_UPDATED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(OPENDOCUMENT_SPREADSHEET, OPENDOCUMENT_GRADE_EXPORTED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(OUTCOMES_REPORT, GRADE_OUTCOMES_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(OVERVIEW_REPORT, GRADE_OVERVIEW_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(PAGE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(QUIZ, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUESTION_MANUALLY_GRADED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_ABANDONED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_PREVIEW_STARTED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_REVIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_STARTED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_SUBMITTED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_SUMMARY_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_ATTEMPT_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_EDIT_PAGE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(QUIZ, QUIZ_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(RECYCLE_BIN, ITEM_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(RECYCLE_BIN, ITEM_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(RECYCLE_BIN, ITEM_RESTORED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(SCORM_PACKAGE, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SCORM_PACKAGE, SCO_LAUNCHED), Default.getInstance()); //TODO
# 		TYPES.put(get(SCORM_PACKAGE, SUBMITTED_SCORM_RAW_SCORE), Default.getInstance()); //TODO
# 		TYPES.put(get(SCORM_PACKAGE, SUBMITTED_SCORM_STATUS), Default.getInstance()); //TODO
#
# 		TYPES.put(get(SINGLE_VIEW, GRADE_SINGLE_VIEW_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(STATISTICS, USER_STATISTICS_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(SUBMISSION_COMMENTS, COMMENT_CREATED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(SURVEY, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SURVEY, SURVEY_REPORT_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SURVEY, SURVEY_RESPONSE_SUBMITTED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(SYSTEM, BADGE_AWARDED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, BADGE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, BADGE_CRITERIA_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, BADGE_ENABLED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, BADGE_LISTING_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, BADGE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, CALENDAR_EVENT_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, CALENDAR_EVENT_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, CALENDAR_EVENT_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, CALENDAR_SUBSCRIPTION_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_ACTIVITY_COMPLETION_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_BACKUP_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_COMPLETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_COMPLETION_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_CONTENT_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_MODULE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_MODULE_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_MODULE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_RESET_ENDED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_RESET_STARTED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_RESTORED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_SECTION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_SECTION_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_SECTION_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_SUMMARY_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_USER_REPORT_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, COURSE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, ENROLMENT_INSTANCE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, ENROLMENT_INSTANCE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, EVIDENCE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GRADE_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUP_ASSIGNED_TO_GROUPING), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUP_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUP_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUP_MEMBER_ADDED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUP_MEMBER_REMOVED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUP_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, GROUPING_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, NOTE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, NOTES_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, QUESTION_CATEGORY_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, RECENT_ACTIVITY_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, ROLE_ASSIGNED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, ROLE_CAPABILITIES_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, ROLE_UNASSIGNED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, TAG_ADDED_TO_AN_ITEM), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_COMPETENCY_RATED_IN_COURSE), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_COMPETENCY_VIEWED_IN_A_COURSE), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_ENROLLED_IN_COURSE), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_GRADED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_PROFILE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(SYSTEM, USER_UNENROLLED_FROM_COURSE), Default.getInstance()); //TODO
#
# 		TYPES.put(get(TURNITIN_ASSIGNMENT_2, ADD_SUBMISSION), Default.getInstance()); //TODO
# 		TYPES.put(get(TURNITIN_ASSIGNMENT_2, LIST_SUBMISSIONS), Default.getInstance()); //TODO
#
# 		TYPES.put(get(URL, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(USER_REPORT, GRADE_USER_REPORT_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(USER_TOURS, STEP_SHOWN), Default.getInstance()); //TODO
# 		TYPES.put(get(USER_TOURS, TOUR_ENDED), Default.getInstance()); //TODO
# 		TYPES.put(get(USER_TOURS, TOUR_STARTED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(WIKI, COMMENT_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, COMMENTS_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, WIKI_HISTORY_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, WIKI_PAGE_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, WIKI_PAGE_LOCKS_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, WIKI_PAGE_MAP_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, WIKI_PAGE_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(WIKI, WIKI_PAGE_VIEWED), Default.getInstance()); //TODO
#
# 		TYPES.put(get(WORKSHOP, A_SUBMISSION_HAS_BEEN_UPLOADED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, ASSESSMENT_EVALUATED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, COURSE_MODULE_INSTANCE_LIST_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, COURSE_MODULE_VIEWED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, PHASE_SWITCHED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, SUBMISSION_ASSESSED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, SUBMISSION_CREATED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, SUBMISSION_DELETED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, SUBMISSION_REASSESSED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, SUBMISSION_UPDATED), Default.getInstance()); //TODO
# 		TYPES.put(get(WORKSHOP, SUBMISSION_VIEWED), Default.getInstance()); //TODO
