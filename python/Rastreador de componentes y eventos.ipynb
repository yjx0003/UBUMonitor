# %%
from tkinter import filedialog
import csv
import tkinter as tk
import json
import re

# %%
#En esta celda permite seleccionar los ficheros csv con ventana y opcionalmente un fichero .json donde se guardan los componentes y eventos encontrados anteriormente
#https://stackoverflow.com/a/42398049
# Create Tk root
root = tk.Tk()
# Hide the main window
root.withdraw()
root.call('wm', 'attributes', '.', '-topmost', True)

csvFiles = filedialog.askopenfilename(multiple=True,filetypes=[("Ficheros CSV",".csv")],title="Selecciona los ficheros CSV")

jsonFile=filedialog.askopenfilename(filetypes=[("Fichero JSON",".json")],title="Selecciona el fichero JSON donde se guarda datos anteriores, si no tienes dale a cancelar")

# %gui tk

# %%
#Cargamos los componentes y eventos si se ha seleccionado fichero json

if len(jsonFile)==0:
    CM={}
else:
    with open(jsonFile,"r",encoding="utf-8") as file:
        CM=json.load(file)
        print("Cargado el JSON", jsonFile)

# %%
for csvFile in csvFiles:
    with open(csvFile,encoding='utf-8') as file:
        reader = csv.DictReader(file, delimiter=',')
        for row in reader:
            component=row["Component"]
            event=row["Event name"]
            
            descripNotNumber=re.sub("\d+", "INTEGER", row["Description"]) #eliminamos los numertuos
            descripNotNumber=re.sub("'[\w]+'","''",row["Description"]) #eliminamos el texto que esta entre comillas simples
            
            
            descriptions=CM.setdefault(component,{}).setdefault(event,[])
            if(descripNotNumber not in descriptions):
                descriptions.append(descripNotNumber)
                if len(descriptions)>1:
                    print("Componente y evento con varias descripciones diferentes:")
                    print("\tComponent: ",component,"\tEvent:",event,"\tDescriptions: ",descriptions)
# Out:
# Componente y evento con varias descripciones diferentes:
# 	Component:  Logs 	Event: Log report viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the log report for the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the log report for the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Course viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the course with id 'INTEGER'.", "The user with id 'INTEGER' viewed the section number 'INTEGER' of the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Course module created 	Descriptions:  ["The user with id 'INTEGER' created the 'quiz' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'assign' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'url' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'page' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'label' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'folder' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'resource' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'book' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'wiki' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'survey' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'glossary' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'feedback' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'data' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'lti' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'chat' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'choice' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'lesson' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'workshop' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' created the 'forum' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' created the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: User graded 	Descriptions:  ["The user with id 'INTEGER' updated the grade with id 'INTEGER' for the user with id 'INTEGER' for the grade item with id 'INTEGER'.", "The user with id '-INTEGER' updated the grade with id 'INTEGER' for the user with id 'INTEGER' for the grade item with id 'INTEGER'.", "The user with id ''.", "The user with id '' updated the grade with id '' for the user with id '' for the grade item with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Scale created 	Descriptions:  ["The user with id 'INTEGER' created the custom scale with id 'INTEGER' from the course with the id 'INTEGER'.", "The user with id ''.", "The user with id '' created the custom scale with id '' from the course with the id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: User profile viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the profile for the user with id 'INTEGER' in the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the profile for the user with id '' in the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Assignment 	Event: Grading form viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the grading form for the user with id 'INTEGER' for the assignment with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the grading form for the user with id '' for the assignment with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Assignment 	Event: The submission has been graded. 	Descriptions:  ["The user with id 'INTEGER' has graded the submission 'INTEGER' for the user with id 'INTEGER' for the assignment with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' has graded the submission '' for the user with id '' for the assignment with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Assignment 	Event: Grading table viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the grading table for the assignment with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the grading table for the assignment with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Assignment 	Event: The status of the submission has been viewed. 	Descriptions:  ["The user with id 'INTEGER' has viewed the submission status page for the assignment with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' has viewed the submission status page for the assignment with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Quiz 	Event: Quiz report viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the report 'overview' for the quiz with course module id 'INTEGER'.", "The user with id 'INTEGER' viewed the report 'statistics' for the quiz with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the report '' for the quiz with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Quiz 	Event: Course module viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the 'quiz' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Forum 	Event: Course module viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the 'forum' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Course activity completion updated 	Descriptions:  ["The user with id 'INTEGER' updated the completion state for the course module with id 'INTEGER' for the user with id 'INTEGER'.", "The user with id ''.", "The user with id '' updated the completion state for the course module with id '' for the user with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Course module deleted 	Descriptions:  ["The user with id 'INTEGER' deleted the 'assign' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' deleted the 'folder' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' deleted the 'page' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' deleted the 'resource' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' deleted the 'quiz' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' deleted the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event deleted 	Descriptions:  ["The user with id 'INTEGER' deleted the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Úndecima entrega EINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Octava EINTEGER-Bis fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Sentencias de Control opens' with id 'INTEGER'.", "The user with id ''Tarea1 pendiente de revisión''.", "The user with id ''Tarea1 fecha de entrega''.", "The user with id ''[MP] Úndecima entrega E11 - Excepción (Fecha de entrega)''.", "The user with id ''[MP] Octava E08-Bis fecha de entrega''.", "The user with id ''.", "The user with id '' deleted the event 'Tarea1 pendiente de revisión''2'."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event deleted 	Descriptions:  ["The user with id 'INTEGER' deleted the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Úndecima entrega EINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Octava EINTEGER-Bis fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' deleted the event '[MP] Sentencias de Control opens' with id 'INTEGER'.", "The user with id ''Tarea1 pendiente de revisión''.", "The user with id ''Tarea1 fecha de entrega''.", "The user with id ''[MP] Úndecima entrega E11 - Excepción (Fecha de entrega)''.", "The user with id ''[MP] Octava E08-Bis fecha de entrega''.", "The user with id ''.", "The user with id '' deleted the event 'Tarea1 pendiente de revisión''2'.", "The user with id '' deleted the event 'Tarea1 fecha de entrega''1'."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Grade deleted 	Descriptions:  ["The user with id 'INTEGER' deleted the grade with id 'INTEGER' for the user with id 'INTEGER' for the grade item with id 'INTEGER'.", "The user with id ''.", "The user with id '' deleted the grade with id '' for the user with id '' for the grade item with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Workshop 	Event: Course module viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the 'workshop' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: User list viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the list of users in the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the list of users in the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Course module updated 	Descriptions:  ["The user with id 'INTEGER' updated the 'choice' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'quiz' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'assign' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'folder' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'label' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'forum' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'resource' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'page' activity with course module id 'INTEGER'.", "The user with id 'INTEGER' updated the 'url' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' updated the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Choice 	Event: Course module viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the 'choice' activity with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the '' activity with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Logs 	Event: User log report viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the user log report for the user with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the user log report for the user with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Forum 	Event: Discussion viewed 	Descriptions:  ["The user with id 'INTEGER' has viewed the discussion with id 'INTEGER' in the forum with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' has viewed the discussion with id '' in the forum with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Forum 	Event: Discussion subscription created 	Descriptions:  ["The user with id 'INTEGER' subscribed the user with id 'INTEGER' to the discussion  with id 'INTEGER' in the forum with the course module id 'INTEGER'.", "The user with id ''.", "The user with id '' subscribed the user with id '' to the discussion  with id '' in the forum with the course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Forum 	Event: Discussion created 	Descriptions:  ["The user with id 'INTEGER' has created the discussion with id 'INTEGER' in the forum with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' has created the discussion with id '' in the forum with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Forum 	Event: Some content has been posted. 	Descriptions:  ["The user with id 'INTEGER' has posted content in the forum post with id 'INTEGER' in the discussion 'INTEGER' located in the forum with course module id 'INTEGER'.", "The user with id ''.", "The user with id '' has posted content in the forum post with id '' in the discussion '' located in the forum with course module id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Activity report 	Event: Activity report viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the outline activity report for the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the outline activity report for the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Group member added 	Descriptions:  ["The user with id 'INTEGER' added the user with id 'INTEGER' to the group with id 'INTEGER'.", "The user with id ''.", "The user with id '' added the user with id '' to the group with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Group created 	Descriptions:  ["The user with id 'INTEGER' created the group with id 'INTEGER'.", "The user with id ''.", "The user with id '' created the group with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Grouping created 	Descriptions:  ["The user with id 'INTEGER' created the grouping with id 'INTEGER'.", "The user with id ''.", "The user with id '' created the grouping with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Course updated 	Descriptions:  ["The user with id 'INTEGER' updated the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' updated the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  Live logs 	Event: Live log report viewed 	Descriptions:  ["The user with id 'INTEGER' viewed the live log report for the course with id 'INTEGER'.", "The user with id ''.", "The user with id '' viewed the live log report for the course with id ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  System 	Event: Calendar event created 	Descriptions:  ["The user with id 'INTEGER' created the event 'Tarea Con Escala pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Tarea Con Escala fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'TareaINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica INTEGER-Primera convocatoria-Damas INTEGER.INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER - Excepción (Fecha de entrega)' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre cierran' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Recuperación de clase práctica del INTEGER de noviembre abren' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuestionario Práctica Obligatoria INTEGER-Grupo INTEGERL closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava entrega EINTEGER fecha de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de revisión' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sentencias de Control closes' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER-Bis pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] - entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Décima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Duodécima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Úndecima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Octava EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.a pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega de Práctica Obligatoria INTEGER - EPOINTEGER-INTEGERC pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER (INTEGERª Convocatoria) pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Entrega Práctica Obligatoria INTEGER - EPOINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Séptima entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Sexta entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Prueba escrita INTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Quinta entrega EINTEGER.b pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Cuarta Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Tercera Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Segunda Entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event '[MP] Primera entrega EINTEGER pendiente de entrega' with id 'INTEGER'.", "The user with id 'INTEGER' created the event 'Encuesta de evaluación docente-Metodología de la programación-IN ...
# Componente y evento con varias descripciones diferentes:
# 	Component:  User tours 	Event: Tour ended 	Descriptions:  ["The user with id 'INTEGER' has ended the tour with id 'INTEGER' at step index 'INTEGER' (id 'INTEGER') on the page with URL 'http://localhost/course/view.php?id=INTEGER'.", "The user with id 'INTEGER' has ended the tour with id 'INTEGER' at step index 'INTEGER' (id 'INTEGER') on the page with URL 'https://ubuvirtual.ubu.es/course/view.php?id=INTEGER'.", "The user with id '') on the page with URL ''.", "The user with id '' has ended the tour with id '' at step index '' (id '') on the page with URL ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  User tours 	Event: Step shown 	Descriptions:  ["The user with id 'INTEGER' has viewed the tour with id 'INTEGER' at step index 'INTEGER' (id 'INTEGER') on the page with URL 'http://localhost/course/view.php?id=INTEGER'.", "The user with id 'INTEGER' has viewed the tour with id 'INTEGER' at step index 'INTEGER' (id 'INTEGER') on the page with URL 'https://ubuvirtual.ubu.es/course/view.php?id=INTEGER'.", "The user with id '') on the page with URL ''.", "The user with id '' has viewed the tour with id '' at step index '' (id '') on the page with URL ''."]
# Componente y evento con varias descripciones diferentes:
# 	Component:  User tours 	Event: Tour started
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
#Guardamos como JSON
#mantenemos el nombre original del json y sino los llamamos componentes y eventos
filename=  jsonFile if len(jsonFile)>0 else "Componentes y eventos.json" 
with open(filename, 'w',encoding='utf-8' ) as f:
    json.dump( CM, f,indent=4,sort_keys=True,ensure_ascii=False )
    print("Guardado como JSON")
# Out:
# Guardado como JSON
